# %%
# !mkdir known
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Bill_Gates_2014.jpg/454px-Bill_Gates_2014.jpg -O known/bill.jpg
# !wget https://i.pinimg.com/736x/39/ab/f5/39abf539e80f88a1bc53781946743e36.jpg -O known/sara.jpg
# !wget https://tentulogo.com/wp-content/uploads/Mark-Zuckerberg.jpg -O known/mark.jpg
# Out:
# mkdir: cannot create directory ‘known’: File exists
# --2020-09-24 12:08:13--  https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Bill_Gates_2014.jpg/454px-Bill_Gates_2014.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.153.240, 2620:0:860:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.153.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56604 (55K) [image/jpeg]
# Saving to: ‘known/bill.jpg’
#
# known/bill.jpg      100%[===================>]  55.28K  29.6KB/s    in 1.9s
#
# 2020-09-24 12:08:16 (29.6 KB/s) - ‘known/bill.jpg’ saved [56604/56604]
#
# --2020-09-24 12:08:16--  https://i.pinimg.com/736x/39/ab/f5/39abf539e80f88a1bc53781946743e36.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 96.6.205.194, 2600:1419:1c00:3a2::1931, 2600:1419:1c00:3af::1931, ...
# Connecting to i.pinimg.com (i.pinimg.com)|96.6.205.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96521 (94K) [image/jpeg]
# Saving to: ‘known/sara.jpg’
#
# known/sara.jpg      100%[===================>]  94.26K  --.-KB/s    in 0.08s
#
# 2020-09-24 12:08:16 (1.15 MB/s) - ‘known/sara.jpg’ saved [96521/96521]
#
# --2020-09-24 12:08:16--  https://tentulogo.com/wp-content/uploads/Mark-Zuckerberg.jpg
# Resolving tentulogo.com (tentulogo.com)... 77.246.188.204
# Connecting to tentulogo.com (tentulogo.com)|77.246.188.204|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 135712 (133K) [image/jpeg]
# Saving to: ‘known/mark.jpg’
#
# known/mark.jpg      100%[===================>] 132.53K   181KB/s    in 0.7s
#
# 2020-09-24 12:08:19 (181 KB/s) - ‘known/mark.jpg’ saved [135712/135712]

# %%
# !mkdir unknown
# !wget https://cnet3.cbsistatic.com/img/oL_IyDK6LMHlH4HBH8hyNqmAh6s=/940x0/2019/02/28/38e55267-ea0d-4e3d-bd39-56e6fab0c220/20160222-facebook-ceo-mark-zuckerberg-01.jpg -O unknown/1.jpg
# !wget https://www.irishtimes.com/polopoly_fs/1.4122962.1576969156!/image/image.jpg_gen/derivatives/box_1200_630/image.jpg -O unknown/2.jpg
# !wget https://www.biografiasyvidas.com/biografia/g/fotos/gates_bill_1.jpg -O unknown/3.jpg
# !wget https://www.biography.com/.image/t_share/MTY2MzU3OTcxMTUwODQxNTM1/steve-jobs--david-paul-morrisbloomberg-via-getty-images.jpg -O unknown/4.jpg
# !wget https://cdn.ticbeat.com/src/uploads/2016/12/Bill_Gates-810x540.jpg -O unknown/5.jpg
# !wget https://e00-telva.uecdn.es/assets/multimedia/imagenes/2020/04/12/15866787966771.jpg -O unknown/6.jpg
# !wget https://www.elimparcial.es/galerias-noticias/galerias/4138/medium/saorise2.jpg -O unknown/7.jpg
# Out:
# mkdir: cannot create directory ‘unknown’: File exists
# --2020-09-24 12:08:19--  https://cnet3.cbsistatic.com/img/oL_IyDK6LMHlH4HBH8hyNqmAh6s=/940x0/2019/02/28/38e55267-ea0d-4e3d-bd39-56e6fab0c220/20160222-facebook-ceo-mark-zuckerberg-01.jpg
# Resolving cnet3.cbsistatic.com (cnet3.cbsistatic.com)... 151.101.205.188, 2a04:4e42:30::444
# Connecting to cnet3.cbsistatic.com (cnet3.cbsistatic.com)|151.101.205.188|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51573 (50K) [image/jpeg]
# Saving to: ‘unknown/1.jpg’
#
# unknown/1.jpg       100%[===================>]  50.36K   162KB/s    in 0.3s
#
# 2020-09-24 12:08:20 (162 KB/s) - ‘unknown/1.jpg’ saved [51573/51573]
#
# --2020-09-24 12:08:20--  https://www.irishtimes.com/polopoly_fs/1.4122962.1576969156!/image/image.jpg_gen/derivatives/box_1200_630/image.jpg
# Resolving www.irishtimes.com (www.irishtimes.com)... 151.101.94.174
# Connecting to www.irishtimes.com (www.irishtimes.com)|151.101.94.174|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116763 (114K) [image/jpeg]
# Saving to: ‘unknown/2.jpg’
#
# unknown/2.jpg       100%[===================>] 114.03K  44.3KB/s    in 2.6s
#
# 2020-09-24 12:08:23 (44.3 KB/s) - ‘unknown/2.jpg’ saved [116763/116763]
#
# --2020-09-24 12:08:23--  https://www.biografiasyvidas.com/biografia/g/fotos/gates_bill_1.jpg
# Resolving www.biografiasyvidas.com (www.biografiasyvidas.com)... 69.16.245.81
# Connecting to www.biografiasyvidas.com (www.biografiasyvidas.com)|69.16.245.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19673 (19K) [image/jpeg]
# Saving to: ‘unknown/3.jpg’
#
# unknown/3.jpg       100%[===================>]  19.21K   114KB/s    in 0.2s
#
# 2020-09-24 12:08:25 (114 KB/s) - ‘unknown/3.jpg’ saved [19673/19673]
#
# --2020-09-24 12:08:25--  https://www.biography.com/.image/t_share/MTY2MzU3OTcxMTUwODQxNTM1/steve-jobs--david-paul-morrisbloomberg-via-getty-images.jpg
# Resolving www.biography.com (www.biography.com)... 151.101.194.98, 151.101.66.98, 151.101.130.98, ...
# Connecting to www.biography.com (www.biography.com)|151.101.194.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 181188 (177K) [image/jpeg]
# Saving to: ‘unknown/4.jpg’
#
# unknown/4.jpg       100%[===================>] 176.94K   884KB/s    in 0.2s
#
# 2020-09-24 12:08:25 (884 KB/s) - ‘unknown/4.jpg’ saved [181188/181188]
#
# --2020-09-24 12:08:25--  https://cdn.ticbeat.com/src/uploads/2016/12/Bill_Gates-810x540.jpg
# Resolving cdn.ticbeat.com (cdn.ticbeat.com)... 172.67.193.156, 104.18.42.132, 104.18.43.132, ...
# Connecting to cdn.ticbeat.com (cdn.ticbeat.com)|172.67.193.156|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49464 (48K) [image/jpeg]
# Saving to: ‘unknown/5.jpg’
#
# unknown/5.jpg       100%[===================>]  48.30K  --.-KB/s    in 0.01s
#
# 2020-09-24 12:08:26 (3.73 MB/s) - ‘unknown/5.jpg’ saved [49464/49464]
#
# --2020-09-24 12:08:26--  https://e00-telva.uecdn.es/assets/multimedia/imagenes/2020/04/12/15866787966771.jpg
# Resolving e00-telva.uecdn.es (e00-telva.uecdn.es)... 13.35.109.25, 13.35.109.82, 13.35.109.29, ...
# Connecting to e00-telva.uecdn.es (e00-telva.uecdn.es)|13.35.109.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 350730 (343K) [image/jpeg]
# Saving to: ‘unknown/6.jpg’
#
# unknown/6.jpg       100%[===================>] 342.51K  67.1KB/s    in 5.1s
#
# 2020-09-24 12:08:32 (67.1 KB/s) - ‘unknown/6.jpg’ saved [350730/350730]
#
# --2020-09-24 12:08:32--  https://www.elimparcial.es/galerias-noticias/galerias/4138/medium/saorise2.jpg
# Resolving www.elimparcial.es (www.elimparcial.es)... 172.67.182.45, 104.27.178.164, 104.27.179.164, ...
# Connecting to www.elimparcial.es (www.elimparcial.es)|172.67.182.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31751 (31K) [image/jpeg]
# Saving to: ‘unknown/7.jpg’
#
# unknown/7.jpg       100%[===================>]  31.01K  82.3KB/s    in 0.4s
#
# 2020-09-24 12:08:34 (82.3 KB/s) - ‘unknown/7.jpg’ saved [31751/31751]

# %%
import face_recognition
import cv2
import os
#from google.colab.patches import cv2_imshow
def read_img(path):
    img = cv2.imread(path)
    (h, w) = img.shape[:2]
    width = 500
    ratio = width/float(w)
    height = int(h*ratio)
    
    return cv2.resize(img,(width, height))

known_encodings = []
known_names = []
known_dir = 'known'

for file in os.listdir(known_dir):
    img = read_img(known_dir + '/' + file)
    img_enc = face_recognition.face_encodings(img)[0]
    known_encodings.append(img_enc)
    known_names.append(file.split('.')[0])

  #known_encodings

unknown_dir = 'unknown'
# Se abre el video
for file in os.listdir(unknown_dir):
    # Se obtienen frames del video
    print("Processing",file)
    img = read_img(unknown_dir + '/' + file)
    img_enc = face_recognition.face_encodings(img)[0]

    results = face_recognition.compare_faces(known_encodings, img_enc)
    print(results)
    #face distances
    print(face_recognition.face_distance(known_encodings, img_enc))

    #for i in range(len(results)):
    #if results[i]:
     # print(known_names[i])

    #print(results)

    for i in range(len(results)):
        if results[i]:
            name = known_names[i]
            (top, right, bottom, left) = face_recognition.face_locations(img)[0]
            cv2.rectangle(img, (left, top), (right, bottom), (0,0,225), 2)
            cv2.putText(img, name, (left+2, bottom+20), cv2.FONT_HERSHEY_PLAIN, 0.8, (255,255,255), 1)
            cv2.imshow('Window',img)
            cv2.waitKey(0)
            cv2.destroyAllWindows()
# Out:
# Processing 3.jpg
# [True, False, False, False]
# [0.50736955 0.81844144 0.85523521 0.72636349]
# Processing 5.jpg
# [True, False, False, False]
# [0.51031806 0.75468216 0.77378434 0.67353756]
# Processing 7.jpg
# [False, False, True, False]
# [0.85762447 0.85201061 0.55143359 0.80083383]
# Processing 2.jpg
# [False, False, True, False]
# [0.90279662 0.85468922 0.40445738 0.7933889 ]
# Processing 8.jpeg
# [False, True, False, False]
# [0.7823361  0.27769787 0.90283179 0.88237938]
# Processing 6.jpg
# [False, False, True, False]
# [0.86414339 0.9152746  0.3728069  0.78571352]
# Processing 1.jpg
# [False, False, False, True]
# [0.84327919 0.89465139 0.78821989 0.38853693]
# Processing 9.jpeg
# [False, True, False, False]
# [0.78140555 0.33847187 0.92748067 0.879257  ]
# Processing 4.jpg
# [False, False, False, False]
# [0.72250408 0.8948831  0.96864469 0.88771906]
